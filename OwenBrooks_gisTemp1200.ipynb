# %%
import xarray as xr

ds = xr.open_dataset("gistemp1200_GHCNv4_ERSSTv5.nc")
ds
# Out:
# <xarray.Dataset> Size: 114MB
# Dimensions:      (time: 1754, nv: 2, lat: 90, lon: 180)
# Coordinates:
#   * time         (time) datetime64[ns] 14kB 1880-01-15 1880-02-15 ... 2026-02-15
#   * lat          (lat) float32 360B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   * lon          (lon) float32 720B -179.0 -177.0 -175.0 ... 175.0 177.0 179.0
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds    (time, nv) datetime64[ns] 28kB ...
#     tempanomaly  (time, lat, lon) float32 114MB ...
# Attributes:
#     title:        GISTEMP Surface Temperature Analysis
#     institution:  NASA Goddard Institute for Space Studies
#     source:       http://data.giss.nasa.gov/gistemp/
#     Conventions:  CF-1.6
#     history:      Created 2026-03-09 07:11:49 by SBBX_to_nc 2.0 - ILAND=1200,...

# %%
ds.attrs
# Out:
# {'title': 'GISTEMP Surface Temperature Analysis',
#  'institution': 'NASA Goddard Institute for Space Studies',
#  'source': 'http://data.giss.nasa.gov/gistemp/',
#  'Conventions': 'CF-1.6',
#  'history': 'Created 2026-03-09 07:11:49 by SBBX_to_nc 2.0 - ILAND=1200, IOCEAN=NCDC/ER5, Base: 1951-1980'}

# %%
ds['tempanomaly'].attrs
# Out:
# {'long_name': 'Surface temperature anomaly',
#  'units': 'K',
#  'cell_methods': 'time: mean'}

# %%
ds['tempanomaly'].attrs
# Out:
# {'long_name': 'Surface temperature anomaly',
#  'units': 'K',
#  'cell_methods': 'time: mean'}

# %%
ta = ds['tempanomaly']
ta
# Out:
# <xarray.DataArray 'tempanomaly' (time: 1754, lat: 90, lon: 180)> Size: 114MB
# [28414800 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 14kB 1880-01-15 1880-02-15 ... 2026-02-15
#   * lat      (lat) float32 360B -89.0 -87.0 -85.0 -83.0 ... 83.0 85.0 87.0 89.0
#   * lon      (lon) float32 720B -179.0 -177.0 -175.0 ... 175.0 177.0 179.0
# Attributes:
#     long_name:     Surface temperature anomaly
#     units:         K
#     cell_methods:  time: mean
